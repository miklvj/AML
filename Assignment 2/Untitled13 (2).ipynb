# %%
import tensorflow as tf
from tensorflow.keras.optimizers import SGD
import numpy as np
from sklearn.preprocessing import StandardScaler
import pandas as pd
import matplotlib.pyplot as plt

# %%
def resize_and_normalize_image(image):
    image = tf.image.resize(image,[32, 32])
    image = tf.image.rgb_to_grayscale(image)
    return image / 255.0

def convert_sample(data):

# Create a TensorFlow dataset from the training data features
    dataset = tf.data.Dataset.from_tensor_slices(data)

# Define a function to resize each image in the dataset

# Apply the resize function to each image in the dataset
    resized_dataset = dataset.map(resize_and_normalize_image)

    resized_dataset.batch(32)

# Convert the resized dataset to a NumPy array
    resized_arr = np.array(list(resized_dataset.as_numpy_iterator()))

    return resized_arr

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
device = '/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'

# %%
# Load the training data features

X_train_raw = np.load('/content/gdrive/My Drive/Assignment 2/Xtrain.npy')
print(f'Shape of the raw training data: {X_train_raw.shape}')

X_test_raw = np.load('/content/gdrive/My Drive/Assignment 2/Xtest.npy')
print(f'Shape of the raw test data: {X_test_raw.shape}')

X_train = convert_sample(X_train_raw)
print(f'Shape the resized training data: {X_train.shape}')

X_test = convert_sample(X_test_raw)
print(f'Shape the resized test data: {X_test.shape}')

y_raw = np.load('/content/gdrive/My Drive/Assignment 2/ytrain.npy')
y_raw = y_raw.reshape(-1,1)
print(f'Shape of the raw labels: {y_raw.shape}')
# Out:
# Shape of the raw training data: (26214, 96, 96, 3)
# Shape of the raw test data: (1638, 96, 96, 3)
# Shape the resized training data: (26214, 32, 32, 1)
# Shape the resized test data: (1638, 32, 32, 1)
# Shape of the raw labels: (26214, 1)

# %% [markdown]
# **Lets take a look at the data (images) before and after the transformation:**

# %%
for i in range(3):
    image_1 = X_train_raw[i]
    label_1 = y_raw[i]
    image_2 = X_train[i]
    label_2 = y_raw[i]

    fig, axes = plt.subplots(1, 2, figsize=(10, 5))

    axes[0].imshow(image_1)
    axes[0].set_title(f'Label: {label_1}')
    axes[0].axis('off')

    axes[1].imshow(image_2)
    axes[1].set_title(f'Label: {label_2}')
    axes[1].axis('off')

    plt.show()

# %% [markdown]
# **Create training data for the 3 ensembles:**

# %%
num_ensembles = 3
samples_per_ensemble = X_train.shape[0] // num_ensembles

np.random.seed(42)

for i in range(1, 4):

    indices = np.random.choice(X_train.shape[0], samples_per_ensemble, replace=False)

    X_subset = X_train[indices]
    y_subset = y_raw[indices]

    globals()[f'X_{i}'] = X_subset
    globals()[f'y_{i}'] = y_subset

    X = np.delete(X_train, indices, axis=0)
    y = np.delete(y_raw, indices, axis=0)

# %% [markdown]
# **Print the shape of the ensambles:**

# %%
for i in range(1,4):
    X = globals()[f'X_{i}']
    y = globals()[f'y_{i}']
    print(X.shape)
    print(y.shape)
# Out:
# (8738, 32, 32, 1)
# (8738, 1)
# (8738, 32, 32, 1)
# (8738, 1)
# (8738, 32, 32, 1)
# (8738, 1)

# %% [markdown]
# **Model 1:**

# %%
def build_model_1(neurons_per_layer, activation, weight_regularizer, dropout, batch_norm):
    layers = [tf.keras.layers.Flatten(input_shape=(32, 32, 1))]

    for neurons in neurons_per_layer:
        layers.append(tf.keras.layers.Dense(neurons, activation=activation,
                                            kernel_regularizer=weight_regularizer))
        if batch_norm:
            layers.append(tf.keras.layers.BatchNormalization())
        if dropout:
            layers.append(tf.keras.layers.Dropout(0.05))

    layers.append(tf.keras.layers.Dense(2, activation='softmax'))

    model_1 = tf.keras.models.Sequential(layers)
    model_1.compile(
        loss='sparse_categorical_crossentropy',
        optimizer=tf.keras.optimizers.experimental.SGD(0.001, momentum=0.01),
        metrics=['sparse_categorical_crossentropy', 'accuracy'],
        )

    return model_1

# %% [markdown]
# **Model 2:**

# %%
def build_model_2(neurons_per_layer, activation, weight_regularizer, dropout, batch_norm):
    layers = [tf.keras.layers.Flatten(input_shape=(32, 32, 1))]

    for neurons in neurons_per_layer:
        layers.append(tf.keras.layers.Dense(neurons, activation=activation,
                                            kernel_regularizer=weight_regularizer))
        if batch_norm:
            layers.append(tf.keras.layers.BatchNormalization())
        if dropout:
            layers.append(tf.keras.layers.Dropout(0.5))

    layers.append(tf.keras.layers.Dense(2, activation='softmax'))

    model_2 = tf.keras.models.Sequential(layers)
    model_2.compile(
        loss='sparse_categorical_crossentropy',
        optimizer=tf.keras.optimizers.experimental.Adagrad(0.001),
        metrics=['sparse_categorical_crossentropy', 'accuracy'],
        )

    return model_2

# %% [markdown]
# **Model 3:**

# %%
def build_model_3(neurons_per_layer, activation, weight_regularizer, dropout, batch_norm):
    layers = [tf.keras.layers.Flatten(input_shape=(32, 32, 1))]

    for neurons in neurons_per_layer:
        layers.append(tf.keras.layers.Dense(neurons, activation=activation,
                                            kernel_regularizer=weight_regularizer))
        if batch_norm:
            layers.append(tf.keras.layers.BatchNormalization())
        if dropout:
            layers.append(tf.keras.layers.Dropout(0.1))

    layers.append(tf.keras.layers.Dense(2, activation='softmax'))

    model_3 = tf.keras.models.Sequential(layers)
    model_3.compile(
        loss='sparse_categorical_crossentropy',
        optimizer=tf.keras.optimizers.experimental.SGD(0.0005, momentum=0.001),
        metrics=['sparse_categorical_crossentropy', 'accuracy'],
        )

    return model_3

# %% [markdown]
# **Define for all models:**
#
# - optimal stopping
# - layers
# - validation_split
# - epochs

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                            patience=25,
                                            restore_best_weights=True)

neurons_per_layer_1 = [100, 200, 300, 300, 200, 100, 100]
neurons_per_layer_2 = [128, 128, 128, 264, 1024, 264, 128, 128, 128]
neurons_per_layer_3 = [256, 256, 256, 256, 256, 256, 256]


weight_regularizer_1 = tf.keras.regularizers.L2(0.01)
weight_regularizer_2 = tf.keras.regularizers.L2(0.01)
weight_regularizer_3 = tf.keras.regularizers.L2(0.01)

validation_split = 0.2

epochs = 1000

# %% [markdown]
# **Build the models:**

# %%
model_1 = build_model_1(neurons_per_layer_1, 'relu', weight_regularizer_1, None, True)
model_2 = build_model_2(neurons_per_layer_2, 'relu', weight_regularizer_2, None, True)
model_3 = build_model_3(neurons_per_layer_3, 'relu', weight_regularizer_3, None, True)

model_1.summary()
model_2.summary()
model_3.summary()
# Out:
# Model: "sequential_141"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_141 (Flatten)       (None, 1024)              0
#
#  dense_1221 (Dense)          (None, 100)               102500
#
#  batch_normalization_1080 (  (None, 100)               400
#  BatchNormalization)
#
#  dense_1222 (Dense)          (None, 200)               20200
#
#  batch_normalization_1081 (  (None, 200)               800
#  BatchNormalization)
#
#  dense_1223 (Dense)          (None, 300)               60300
#
#  batch_normalization_1082 (  (None, 300)               1200
#  BatchNormalization)
#
#  dense_1224 (Dense)          (None, 300)               90300
#
#  batch_normalization_1083 (  (None, 300)               1200
#  BatchNormalization)
#
#  dense_1225 (Dense)          (None, 200)               60200
#
#  batch_normalization_1084 (  (None, 200)               800
#  BatchNormalization)
#
#  dense_1226 (Dense)          (None, 100)               20100
#
#  batch_normalization_1085 (  (None, 100)               400
#  BatchNormalization)
#
#  dense_1227 (Dense)          (None, 100)               10100
#
#  batch_normalization_1086 (  (None, 100)               400
#  BatchNormalization)
#
#  dense_1228 (Dense)          (None, 2)                 202
#
# =================================================================
# Total params: 369102 (1.41 MB)
# Trainable params: 366502 (1.40 MB)
# Non-trainable params: 2600 (10.16 KB)
# _________________________________________________________________
# Model: "sequential_142"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_142 (Flatten)       (None, 1024)              0
#
#  dense_1229 (Dense)          (None, 128)               131200
#
#  batch_normalization_1087 (  (None, 128)               512
#  BatchNormalization)
#
#  dense_1230 (Dense)          (None, 128)               16512
#
#  batch_normalization_1088 (  (None, 128)               512
#  BatchNormalization)
#
#  dense_1231 (Dense)          (None, 128)               16512
#
#  batch_normalization_1089 (  (None, 128)               512
#  BatchNormalization)
#
#  dense_1232 (Dense)          (None, 264)               34056
#
#  batch_normalization_1090 (  (None, 264)               1056
#  BatchNormalization)
#
#  dense_1233 (Dense)          (None, 1024)              271360
#
#  batch_normalization_1091 (  (None, 1024)              4096
#  BatchNormalization)
#
#  dense_1234 (Dense)          (None, 264)               270600
#
#  batch_normalization_1092 (  (None, 264)               1056
#  BatchNormalization)
#
#  dense_1235 (Dense)          (None, 128)               33920
#
#  batch_normalization_1093 (  (None, 128)               512
#  BatchNormalization)
#
#  dense_1236 (Dense)          (None, 128)               16512
#
#  batch_normalization_1094 (  (None, 128)               512
#  BatchNormalization)
#
#  dense_1237 (Dense)          (None, 128)               16512
#
#  batch_normalization_1095 (  (None, 128)               512
#  BatchNormalization)
#
#  dense_1238 (Dense)          (None, 2)                 258
#
# =================================================================
# Total params: 816722 (3.12 MB)
# Trainable params: 812082 (3.10 MB)
# Non-trainable params: 4640 (18.12 KB)
# _________________________________________________________________
# Model: "sequential_143"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_143 (Flatten)       (None, 1024)              0
#
#  dense_1239 (Dense)          (None, 256)               262400
#
#  batch_normalization_1096 (  (None, 256)               1024
#  BatchNormalization)
#
#  dense_1240 (Dense)          (None, 256)               65792
#
#  batch_normalization_1097 (  (None, 256)               1024
#  BatchNormalization)
#
#  dense_1241 (Dense)          (None, 256)               65792
#
#  batch_normalization_1098 (  (None, 256)               1024
#  BatchNormalization)
#
#  dense_1242 (Dense)          (None, 256)               65792
#
#  batch_normalization_1099 (  (None, 256)               1024
#  BatchNormalization)
#
#  dense_1243 (Dense)          (None, 256)               65792
#
#  batch_normalization_1100 (  (None, 256)               1024
#  BatchNormalization)
#
#  dense_1244 (Dense)          (None, 256)               65792
#
#  batch_normalization_1101 (  (None, 256)               1024
#  BatchNormalization)
#
#  dense_1245 (Dense)          (None, 256)               65792
#
#  batch_normalization_1102 (  (None, 256)               1024
#  BatchNormalization)
#
#  dense_1246 (Dense)          (None, 2)                 514
#
# =================================================================
# Total params: 664834 (2.54 MB)
# Trainable params: 661250 (2.52 MB)
# Non-trainable params: 3584 (14.00 KB)
# _________________________________________________________________

# %% [markdown]
# **Fit the models:**

# %%
history_1 = model_1.fit(
    X_train,
    y_raw,
    epochs=epochs,
    verbose=1,
    validation_split=validation_split,
    callbacks=callback
)
# Out:
# Epoch 1/1000
# 656/656 [==============================] - 10s 11ms/step - loss: 13.8292 - sparse_categorical_crossentropy: 0.7515 - accuracy: 0.6210 - val_loss: 13.7808 - val_sparse_categorical_crossentropy: 0.8746 - val_accuracy: 0.6136
# Epoch 2/1000
# 656/656 [==============================] - 7s 11ms/step - loss: 13.3780 - sparse_categorical_crossentropy: 0.6401 - accuracy: 0.6663 - val_loss: 13.1944 - val_sparse_categorical_crossentropy: 0.6242 - val_accuracy: 0.6805
# Epoch 3/1000
# 656/656 [==============================] - 7s 11ms/step - loss: 13.0121 - sparse_categorical_crossentropy: 0.6061 - accuracy: 0.6874 - val_loss: 12.8905 - val_sparse_categorical_crossentropy: 0.6480 - val_accuracy: 0.6748
# Epoch 4/1000
# 656/656 [==============================] - 7s 10ms/step - loss: 12.6626 - sparse_categorical_crossentropy: 0.5801 - accuracy: 0.6996 - val_loss: 12.5378 - val_sparse_categorical_crossentropy: 0.6146 - val_accuracy: 0.6817
# Epoch 5/1000
# 656/656 [==============================] - 8s 12ms/step - loss: 12.3360 - sparse_categorical_crossentropy: 0.5687 - accuracy: 0.7095 - val_loss: 12.2004 - val_sparse_categorical_crossentropy: 0.5882 - val_accuracy: 0.7019
# Epoch 6/1000
# 656/656 [==============================] - 8s 12ms/step - loss: 12.0171 - sparse_categorical_crossentropy: 0.5567 - accuracy: 0.7174 - val_loss: 11.8981 - val_sparse_categorical_crossentropy: 0.5889 - val_accuracy: 0.7078
# Epoch 7/1000
# 656/656 [==============================] - 8s 12ms/step - loss: 11.7072 - sparse_categorical_crossentropy: 0.5459 - accuracy: 0.7239 - val_loss: 11.5960 - val_sparse_categorical_crossentropy: 0.5819 - val_accuracy: 0.7149
# Epoch 8/1000
# 656/656 [==============================] - 7s 10ms/step - loss: 11.4031 - sparse_categorical_crossentropy: 0.5330 - accuracy: 0.7331 - val_loss: 11.2975 - val_sparse_categorical_crossentropy: 0.5709 - val_accuracy: 0.7223
# Epoch 9/1000
# 656/656 [==============================] - 7s 11ms/step - loss: 11.1114 - sparse_categorical_crossentropy: 0.5250 - accuracy: 0.7415 - val_loss: 11.0179 - val_sparse_categorical_crossentropy: 0.5712 - val_accuracy: 0.7208
# Epoch 10/1000
# 656/656 [==============================] - 6s 10ms/step - loss: 10.8217 - sparse_categorical_crossentropy: 0.5116 - accuracy: 0.7507 - val_loss: 10.7518 - val_sparse_categorical_crossentropy: 0.5777 - val_accuracy: 0.7187
# Epoch 11/1000
# 518/656 [======================>.......] - ETA: 1s - loss: 10.5721 - sparse_categorical_crossentropy: 0.5033 - accuracy: 0.7578

# %%
history_2 = model_2.fit(
    X_train,
    y_raw,
    epochs=epochs,
    verbose=1,
    validation_split=validation_split,
    callbacks=callback
)

# %%
history_3 = model_3.fit(
    X_train,
    y_raw,
    epochs=epochs,
    verbose=1,
    validation_split=validation_split,
    callbacks=callback
)

# %% [markdown]
# **Model performence:**

# %%
for i in range(1,4):
    history_x = globals()[f'history_{i}']
    history_y = globals()[f'history_{i}']

    fig = plt.figure(figsize=plt.figaspect(0.2))


    ax = fig.add_subplot(1, 2, 1)
    ax.plot(history_x.history['loss'], label='Training loss')
    ax.plot(history_y.history['val_loss'], label='Validation loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Loss over Epochs, Model_{i}')
    plt.legend(loc='upper right')


    ax = fig.add_subplot(1, 2, 2)
    ax.plot(history_x.history['accuracy'], label='Training accuracy')
    ax.plot(history_y.history['val_accuracy'], label='Validation accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title(f'Accuracy over Epochs, Model_{i}')
    plt.legend(loc='lower right')

    plt.show()

# %% [markdown]
# **Majority vote:**

# %%
df_ensemble = pd.DataFrame()

y_test_hat_1 = model_1.predict(X_test)
y_test_hat_1 = np.argmax(y_test_hat_1, axis=1)

y_test_hat_2 = model_2.predict(X_test)
y_test_hat_2 = np.argmax(y_test_hat_2, axis=1)

y_test_hat_3 = model_3.predict(X_test)
y_test_hat_3 = np.argmax(y_test_hat_3, axis=1)

df_ensemble['model_1'] = y_test_hat_1
df_ensemble['model_2'] = y_test_hat_2
df_ensemble['model_3'] = y_test_hat_3

def calculate_majority(row):
  counts = pd.Series(row).value_counts()
  majority = counts.idxmax()
  return majority

df_ensemble['majority'] = df_ensemble.apply(calculate_majority, axis=1)

print(df_ensemble)

# %% [markdown]
# **Final prediction:**

# %%
df_ensemble = pd.DataFrame({
    'Id': range(len(df_ensemble)),
    'Predicted': df_ensemble['majority'].values,
})

path_on_drive = '/content/gdrive/My Drive/Assignment 2/pred.csv'
df_ensemble.to_csv(path_on_drive, index=False)
